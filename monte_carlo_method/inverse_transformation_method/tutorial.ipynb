# %%
from src import InverseTransformationMethod, ExpQuantile

# %%
# 平均0.5の指数分布に従う乱数を生成する
exp_quoatile = ExpQuantile(0.5)
sampler = InverseTransformationMethod(exp_quoatile)

# %%
for i in range(100):
    print(sampler())
# Out:
# 0.7983531975504249
# 3.508427509583402
# 0.30256426580772044
# 0.6689295470606961
# 2.7716082858701796
# 0.2054808267880442
# 2.125887534976705
# 4.596133448414526
# 0.335942472360283
# 2.740633565016238
# 1.070991926742599
# 7.552258099609369
# 2.0486794467052407
# 0.8088781852085833
# 1.7954649182043176
# 0.17530992350682806
# 0.03630760628841459
# 0.8919370981939306
# 2.9350195538155797
# 1.8210966220775218
# 0.352618716028535
# 5.574675311043041
# 1.5203274096198731
# 2.3000388210645544
# 1.3620568842397145
# 2.5257967119857825
# 11.325439799590093
# 0.19422266667399374
# 0.9585847738660176
# 1.3988255757131551
# 1.4284866817718413
# 0.8357578762004076
# 1.9429029728446991
# 0.16237133502219214
# 2.8091020613630153
# 0.014329286869732127
# 2.9333275711520685
# 0.03842735854109048
# 0.016153620505679263
# 0.3504015765290344
# 2.157310398547854
# 0.7274796065136416
# 1.365971873043583
# 0.8099591388122339
# 0.1083944343959078
# 1.0957121683090532
# 2.133601759695752
# ...
